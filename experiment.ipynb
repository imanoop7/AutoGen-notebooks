# %%
config_list = [
    {
        "model": "llama3.2",
        "base_url": "http://localhost:11434/v1",
        'api_key': 'ollama',
    },
]

# %%
import autogen

# %%
llm_config = {"config_list": config_list, "cache_seed": 42}
user_proxy = autogen.UserProxyAgent(
    name="User_proxy",
    system_message="A human admin.",
    code_execution_config={
        "last_n_messages": 2,
        "work_dir": "groupchat",
        "use_docker": False,
    },  # Please set use_docker=True if docker is available to run the generated code. Using docker is safer than running the generated code directly.
    human_input_mode="TERMINATE",
)
coder = autogen.AssistantAgent(
    name="Coder",
    llm_config=llm_config,
)
pm = autogen.AssistantAgent(
    name="Product_manager",
    system_message="Creative in software product ideas.",
    llm_config=llm_config,
)
groupchat = autogen.GroupChat(agents=[user_proxy, coder, pm], messages=[], max_round=12)
manager = autogen.GroupChatManager(groupchat=groupchat, llm_config=llm_config)

# %%
user_proxy.initiate_chat(
    manager, message="Find a latest paper about gpt-4 on arxiv and find its potential applications in software."
)
# type exit to terminate the chat
# Out:
# User_proxy (to chat_manager):
#
# Find a latest paper about gpt-4 on arxiv and find its potential applications in software.
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 user_proxy.initiate_chat(
#       2     manager, message="Find a latest paper about gpt-4 on arxiv and find its potential applications in software."
#       3 )
#       4 # type exit to terminate the chat
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogen\agentchat\conversable_agent.py:1152, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1150     else:
#    1151         msg2send = self.generate_init_message(message, **kwargs)
# -> 1152     self.send(msg2send, recipient, silent=silent)
#    1153 summary = self._summarize_chat(
#    1154     summary_method,
#    1155     summary_args,
#    1156     recipient,
#    1157     cache=cache,
#    1158 )
#    1159 for agent in [self, recipient]:
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogen\agentchat\conversable_agent.py:787, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#     785 valid = self._append_oai_message(message, "assistant", recipient, is_sending=True)
#     786 if valid:
# --> 787     recipient.receive(message, self, request_reply, silent)
#     788 else:
#     789     raise ValueError(
#     790         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     791     )
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogen\agentchat\conversable_agent.py:952, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     950 if request_reply is False or request_reply is None and self.reply_at_receive[sender] is False:
#     951     return
# --> 952 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     953 if reply is not None:
#     954     self.send(reply, sender, silent=silent)
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogen\agentchat\conversable_agent.py:2109, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    2107     continue
#    2108 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 2109     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    2110     if logging_enabled():
#    2111         log_event(
#    2112             self,
#    2113             "reply_func_executed",
#    (...)
#    2117             reply=reply,
#    2118         )
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogen\agentchat\groupchat.py:1169, in GroupChatManager.run_chat(self, messages, sender, config)
#    1166     break
#    1167 try:
#    1168     # select the next speaker
# -> 1169     speaker = groupchat.select_speaker(speaker, self)
#    1170     if not silent:
#    1171         iostream = IOStream.get_default()
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogen\agentchat\groupchat.py:563, in GroupChat.select_speaker(self, last_speaker, selector)
#     560     return self.next_agent(last_speaker)
#     562 # auto speaker selection with 2-agent chat
# --> 563 return self._auto_select_speaker(last_speaker, selector, messages, agents)
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogen\agentchat\groupchat.py:741, in GroupChat._auto_select_speaker(self, last_speaker, selector, messages, agents)
#     738     self._speaker_selection_transforms.add_to_agent(speaker_selection_agent)
#     740 # Run the speaker selection chat
# --> 741 result = checking_agent.initiate_chat(
#     742     speaker_selection_agent,
#     743     cache=None,  # don't use caching for the speaker selection chat
#     744     message=start_message,
#     745     max_turns=2
#     746     * max(1, max_attempts),  # Limiting the chat to the number of attempts, including the initial one
#     747     clear_history=False,
#     748     silent=not self.select_speaker_auto_verbose,  # Base silence on the verbose attribute
#     749 )
#     751 return self._process_speaker_selection_result(result, last_speaker, agents)
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogen\agentchat\conversable_agent.py:1145, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1143         if msg2send is None:
#    1144             break
# -> 1145         self.send(msg2send, recipient, request_reply=True, silent=silent)
#    1146 else:
#    1147     self._prepare_chat(recipient, clear_history)
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogen\agentchat\conversable_agent.py:787, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#     785 valid = self._append_oai_message(message, "assistant", recipient, is_sending=True)
#     786 if valid:
# --> 787     recipient.receive(message, self, request_reply, silent)
#     788 else:
#     789     raise ValueError(
#     790         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     791     )
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogen\agentchat\conversable_agent.py:952, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     950 if request_reply is False or request_reply is None and self.reply_at_receive[sender] is False:
#     951     return
# --> 952 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     953 if reply is not None:
#     954     self.send(reply, sender, silent=silent)
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogen\agentchat\conversable_agent.py:2109, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    2107     continue
#    2108 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 2109     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    2110     if logging_enabled():
#    2111         log_event(
#    2112             self,
#    2113             "reply_func_executed",
#    (...)
#    2117             reply=reply,
#    2118         )
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogen\agentchat\conversable_agent.py:1474, in ConversableAgent.generate_oai_reply(self, messages, sender, config)
#    1472 if messages is None:
#    1473     messages = self._oai_messages[sender]
# -> 1474 extracted_response = self._generate_oai_reply_from_client(
#    1475     client, self._oai_system_message + messages, self.client_cache
#    1476 )
#    1477 return (False, None) if extracted_response is None else (True, extracted_response)
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogen\agentchat\conversable_agent.py:1493, in ConversableAgent._generate_oai_reply_from_client(self, llm_client, messages, cache)
#    1490         all_messages.append(message)
#    1492 # TODO: #1143 handle token limit exceeded error
# -> 1493 response = llm_client.create(
#    1494     context=messages[-1].pop("context", None),
#    1495     messages=all_messages,
#    1496     cache=cache,
#    1497     agent=self,
#    1498 )
#    1499 extracted_response = llm_client.extract_text_or_completion_object(response)[0]
#    1501 if extracted_response is None:
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogen\oai\client.py:869, in OpenAIWrapper.create(self, **config)
#     867 try:
#     868     request_ts = get_current_ts()
# --> 869     response = client.create(params)
#     870 except APITimeoutError as err:
#     871     logger.debug(f"config {i} timed out", exc_info=True)
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogen\oai\client.py:423, in OpenAIClient.create(self, params)
#     421     params = params.copy()
#     422     params["stream"] = False
# --> 423     response = create_or_parse(**params)
#     425 return response
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\resources\chat\completions.py:829, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     788 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     789 def create(
#     790     self,
#    (...)
#     826     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     827 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     828     validate_response_format(response_format)
# --> 829     return self._post(
#     830         "/chat/completions",
#     831         body=maybe_transform(
#     832             {
#     833                 "messages": messages,
#     834                 "model": model,
#     835                 "audio": audio,
#     836                 "frequency_penalty": frequency_penalty,
#     837                 "function_call": function_call,
#     838                 "functions": functions,
#     839                 "logit_bias": logit_bias,
#     840                 "logprobs": logprobs,
#     841                 "max_completion_tokens": max_completion_tokens,
#     842                 "max_tokens": max_tokens,
#     843                 "metadata": metadata,
#     844                 "modalities": modalities,
#     845                 "n": n,
#     846                 "parallel_tool_calls": parallel_tool_calls,
#     847                 "prediction": prediction,
#     848                 "presence_penalty": presence_penalty,
#     849                 "response_format": response_format,
#     850                 "seed": seed,
#     851                 "service_tier": service_tier,
#     852                 "stop": stop,
#     853                 "store": store,
#     854                 "stream": stream,
#     855                 "stream_options": stream_options,
#     856                 "temperature": temperature,
#     857                 "tool_choice": tool_choice,
#     858                 "tools": tools,
#     859                 "top_logprobs": top_logprobs,
#     860                 "top_p": top_p,
#     861                 "user": user,
#     862             },
#     863             completion_create_params.CompletionCreateParams,
#     864         ),
#     865         options=make_request_options(
#     866             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     867         ),
#     868         cast_to=ChatCompletion,
#     869         stream=stream or False,
#     870         stream_cls=Stream[ChatCompletionChunk],
#     871     )
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_base_client.py:1278, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1264 def post(
#    1265     self,
#    1266     path: str,
#    (...)
#    1273     stream_cls: type[_StreamT] | None = None,
#    1274 ) -> ResponseT | _StreamT:
#    1275     opts = FinalRequestOptions.construct(
#    1276         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1277     )
# -> 1278     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_base_client.py:955, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     952 else:
#     953     retries_taken = 0
# --> 955 return self._request(
#     956     cast_to=cast_to,
#     957     options=options,
#     958     stream=stream,
#     959     stream_cls=stream_cls,
#     960     retries_taken=retries_taken,
#     961 )
#
# File c:\Users\anoop\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_base_client.py:1059, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1056         err.response.read()
#    1058     log.debug("Re-raising status error")
# -> 1059     raise self._make_status_error_from_response(err.response) from None
#    1061 return self._process_response(
#    1062     cast_to=cast_to,
#    1063     options=options,
#    (...)
#    1067     retries_taken=retries_taken,
#    1068 )
#
# NotFoundError: Error code: 404 - {'error': {'message': 'model "llama3" not found, try pulling it first', 'type': 'api_error', 'param': None, 'code': None}}
